# %%
from astropy.io import fits as pf
from scipy import signal
import matplotlib.pyplot as pl

# %%
ff=pf.open('thar.fits')

# %%
reflux=ff[0].data

# %%
reflux[20000:20005]
# Out:
# array([2806.278  ,  670.8556 ,  688.64496, 1439.4644 , 2043.5834 ],
#       dtype=float32)

# %%
pl.plot(reflux[20000:30000])

# %%
reflux_sub = reflux[20000:30000].copy()

# %%
taper = signal.windows.tukey(len(reflux_sub), alpha=0.2)

# %%
reflux_sub *= taper

# %%
pl.plot(reflux_sub)

# %%
pl.plot(reflux[20000:30000])

# %%
reflux[20000:20005]

# %%
reflux_sub[0:5]

# %%
pl.plot(taper)
